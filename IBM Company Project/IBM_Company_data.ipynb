# %%
import pandas as pd 
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv(r"C:\Users\LENOVO\Downloads\IBM company\test.csv")
df2 = pd.read_csv(r"C:\Users\LENOVO\Downloads\IBM company\train.csv")

df = pd.merge(df1, df2, left_on='Age', right_on='Age')
df.to_csv('file3.xlsx', index=False)

# %%
df
# Out:
#        Age BusinessTravel_x  DailyRate_x Department_x  DistanceFromHome_x  \
# 0       34    Travel_Rarely          790        Sales                  24
# 1       34    Travel_Rarely          790        Sales                  24
# 2       34    Travel_Rarely          790        Sales                  24
# 3       34    Travel_Rarely          790        Sales                  24
# 4       34    Travel_Rarely          790        Sales                  24
# ...    ...              ...          ...          ...                 ...
# 14113   52       Non-Travel          585        Sales                  29
# 14114   52       Non-Travel          585        Sales                  29
# 14115   52       Non-Travel          585        Sales                  29
# 14116   52       Non-Travel          585        Sales                  29
# 14117   52       Non-Travel          585        Sales                  29
#
#        Education_x EducationField_x  EmployeeCount_x  EmployeeNumber_x  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                          0
# BusinessTravel_x             0
# DailyRate_x                  0
# Department_x                 0
# DistanceFromHome_x           0
#                             ..
# WorkLifeBalance_y            0
# YearsAtCompany_y             0
# YearsInCurrentRole_y         0
# YearsSinceLastPromotion_y    0
# YearsWithCurrManager_y       0
# Length: 68, dtype: int64

# %%
df.to_csv(r"C:\Users\LENOVO\Downloads\IBM_Company_data.csv")

# %%
df['Status'].value_counts().plot(kind='bar',figsize=(6,4),title=" Status Count ")

# %%
df.drop_duplicates ()
# Out:
#        Age BusinessTravel_x  DailyRate_x Department_x  DistanceFromHome_x  \
# 0       34    Travel_Rarely          790        Sales                  24
# 1       34    Travel_Rarely          790        Sales                  24
# 2       34    Travel_Rarely          790        Sales                  24
# 3       34    Travel_Rarely          790        Sales                  24
# 4       34    Travel_Rarely          790        Sales                  24
# ...    ...              ...          ...          ...                 ...
# 14113   52       Non-Travel          585        Sales                  29
# 14114   52       Non-Travel          585        Sales                  29
# 14115   52       Non-Travel          585        Sales                  29
# 14116   52       Non-Travel          585        Sales                  29
# 14117   52       Non-Travel          585        Sales                  29
#
#        Education_x EducationField_x  EmployeeCount_x  EmployeeNumber_x  \
# ...
